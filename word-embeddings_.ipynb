# %% [markdown]
# Notebook prepared by Henrique Lopes Cardoso (hlc@fe.up.pt), based on [Word2Vec Tutorial Notebook](https://github.com/kavgan/nlp-in-practice/tree/master/word2vec) by Kavita Ganesan and on [Gensim's documentation on the Word2Vec Model](https://radimrehurek.com/gensim/auto_examples/tutorials/run_word2vec.html).
#
# # WORD EMBEDDINGS

# %% [markdown]
# ## Word2Vec in Gensim
#
# [Word2Vec](https://code.google.com/archive/p/word2vec/) is a model for training word embeddings that revolutionized the way words are represented. [Gensim](https://radimrehurek.com/gensim_3.8.3/models/word2vec.html) provides an implementation of the algorithm, with which we can train our own word embeddings.

# %% [markdown]
# #### The data
#
# Training embeddings requires a big corpus, the bigger the better.
#
# For illustration purposes, we'll make use of the (not very big) [OpinRank](http://kavita-ganesan.com/entity-ranking-data/) dataset, which includes full reviews of cars and hotels. More specifically, we'll use an 84MB compressed file with 255404 hotel reviews.
#
# This is how each review looks like:

# %%
import gzip

data_file="reviews_data.txt.gz"

with gzip.open ('reviews_data.txt.gz', 'rb') as f:
    for i,line in enumerate (f):
        print(line)
        break
# Out:
# b"Oct 12 2009 \tNice trendy hotel location not too bad.\tI stayed in this hotel for one night. As this is a fairly new place some of the taxi drivers did not know where it was and/or did not want to drive there. Once I have eventually arrived at the hotel, I was very pleasantly surprised with the decor of the lobby/ground floor area. It was very stylish and modern. I found the reception's staff geeting me with 'Aloha' a bit out of place, but I guess they are briefed to say that to keep up the coroporate image.As I have a Starwood Preferred Guest member, I was given a small gift upon-check in. It was only a couple of fridge magnets in a gift box, but nevertheless a nice gesture.My room was nice and roomy, there are tea and coffee facilities in each room and you get two complimentary bottles of water plus some toiletries by 'bliss'.The location is not great. It is at the last metro stop and you then need to take a taxi, but if you are not planning on going to see the historic sites in Beijing, then you will be ok.I chose to have some breakfast in the hotel, which was really tasty and there was a good selection of dishes. There are a couple of computers to use in the communal area, as well as a pool table. There is also a small swimming pool and a gym area.I would definitely stay in this hotel again, but only if I did not plan to travel to central Beijing, as it can take a long time. The location is ok if you plan to do a lot of shopping, as there is a big shopping centre just few minutes away from the hotel and there are plenty of eating options around, including restaurants that serve a dog meat!\t\r\n"

# %% [markdown]
# Let's read the whole dataset into a list, while providing some logging information.
#
# In the process of reading the data directly from the compressed file, we'll perform some pre-processing of the reviews using [gensim.utils.simple_preprocess](https://tedboy.github.io/nlps/generated/generated/gensim.utils.simple_preprocess.html). This does some basic pre-processing such as tokenization and lowercasing, and returns back a list of tokens (words).

# %%
import gensim
import logging

logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

def read_input(input_file):
    """This method reads the input file which is in gzip format"""
    
    logging.info("reading file {0}...this may take a while".format(input_file))
    
    with gzip.open (input_file, 'rb') as f:
        for i, line in enumerate (f): 

            if (i%10000==0):
                logging.info ("read {0} reviews".format (i))
            # do some pre-processing and return a list of words for each review text
            yield gensim.utils.simple_preprocess(line)
    logging.info("Done reading data file")

# %%
# compressed file with the data
data_file="reviews_data.txt.gz"

# read the tokenized reviews into a list
documents = list(read_input(data_file))

len(documents)
# Out:
# 2023-03-10 12:11:33,341 : INFO : reading file reviews_data.txt.gz...this may take a while
# 2023-03-10 12:11:33,342 : INFO : read 0 reviews
# 2023-03-10 12:11:35,816 : INFO : read 10000 reviews
# 2023-03-10 12:11:38,332 : INFO : read 20000 reviews
# 2023-03-10 12:11:41,508 : INFO : read 30000 reviews
# 2023-03-10 12:11:44,362 : INFO : read 40000 reviews
# 2023-03-10 12:11:47,477 : INFO : read 50000 reviews
# 2023-03-10 12:11:50,166 : INFO : read 60000 reviews
# 2023-03-10 12:11:52,662 : INFO : read 70000 reviews
# 2023-03-10 12:11:54,667 : INFO : read 80000 reviews
# 2023-03-10 12:11:59,259 : INFO : read 90000 reviews
# 2023-03-10 12:12:02,165 : INFO : read 100000 reviews
# 2023-03-10 12:12:05,066 : INFO : read 110000 reviews
# 2023-03-10 12:12:07,722 : INFO : read 120000 reviews
# 2023-03-10 12:12:12,396 : INFO : read 130000 reviews
# 2023-03-10 12:12:17,664 : INFO : read 140000 reviews
# 2023-03-10 12:12:20,224 : INFO : read 150000 reviews
# 2023-03-10 12:12:22,910 : INFO : read 160000 reviews
# 2023-03-10 12:12:25,802 : INFO : read 170000 reviews
# 2023-03-10 12:12:28,186 : INFO : read 180000 reviews
# 2023-03-10 12:12:33,517 : INFO : read 190000 reviews
# 2023-03-10 12:13:02,183 : INFO : read 200000 reviews
# 2023-03-10 12:13:07,792 : INFO : read 210000 reviews
# 2023-03-10 12:13:11,889 : INFO : read 220000 reviews
# 2023-03-10 12:13:15,452 : INFO : read 230000 reviews
# 2023-03-10 12:13:19,216 : INFO : read 240000 reviews
# 2023-03-10 12:13:22,804 : INFO : read 250000 reviews
# 2023-03-10 12:13:25,081 : INFO : Done reading data file
# 255404

# %% [markdown]
# Each review item becomes a list of words, so what we have is a list of lists.

# %%
print(documents[0])
# Out:
# ['oct', 'nice', 'trendy', 'hotel', 'location', 'not', 'too', 'bad', 'stayed', 'in', 'this', 'hotel', 'for', 'one', 'night', 'as', 'this', 'is', 'fairly', 'new', 'place', 'some', 'of', 'the', 'taxi', 'drivers', 'did', 'not', 'know', 'where', 'it', 'was', 'and', 'or', 'did', 'not', 'want', 'to', 'drive', 'there', 'once', 'have', 'eventually', 'arrived', 'at', 'the', 'hotel', 'was', 'very', 'pleasantly', 'surprised', 'with', 'the', 'decor', 'of', 'the', 'lobby', 'ground', 'floor', 'area', 'it', 'was', 'very', 'stylish', 'and', 'modern', 'found', 'the', 'reception', 'staff', 'geeting', 'me', 'with', 'aloha', 'bit', 'out', 'of', 'place', 'but', 'guess', 'they', 'are', 'briefed', 'to', 'say', 'that', 'to', 'keep', 'up', 'the', 'coroporate', 'image', 'as', 'have', 'starwood', 'preferred', 'guest', 'member', 'was', 'given', 'small', 'gift', 'upon', 'check', 'in', 'it', 'was', 'only', 'couple', 'of', 'fridge', 'magnets', 'in', 'gift', 'box', 'but', 'nevertheless', 'nice', 'gesture', 'my', 'room', 'was', 'nice', 'and', 'roomy', 'there', 'are', 'tea', 'and', 'coffee', 'facilities', 'in', 'each', 'room', 'and', 'you', 'get', 'two', 'complimentary', 'bottles', 'of', 'water', 'plus', 'some', 'toiletries', 'by', 'bliss', 'the', 'location', 'is', 'not', 'great', 'it', 'is', 'at', 'the', 'last', 'metro', 'stop', 'and', 'you', 'then', 'need', 'to', 'take', 'taxi', 'but', 'if', 'you', 'are', 'not', 'planning', 'on', 'going', 'to', 'see', 'the', 'historic', 'sites', 'in', 'beijing', 'then', 'you', 'will', 'be', 'ok', 'chose', 'to', 'have', 'some', 'breakfast', 'in', 'the', 'hotel', 'which', 'was', 'really', 'tasty', 'and', 'there', 'was', 'good', 'selection', 'of', 'dishes', 'there', 'are', 'couple', 'of', 'computers', 'to', 'use', 'in', 'the', 'communal', 'area', 'as', 'well', 'as', 'pool', 'table', 'there', 'is', 'also', 'small', 'swimming', 'pool', 'and', 'gym', 'area', 'would', 'definitely', 'stay', 'in', 'this', 'hotel', 'again', 'but', 'only', 'if', 'did', 'not', 'plan', 'to', 'travel', 'to', 'central', 'beijing', 'as', 'it', 'can', 'take', 'long', 'time', 'the', 'location', 'is', 'ok', 'if', 'you', 'plan', 'to', 'do', 'lot', 'of', 'shopping', 'as', 'there', 'is', 'big', 'shopping', 'centre', 'just', 'few', 'minutes', 'away', 'from', 'the', 'hotel', 'and', 'there', 'are', 'plenty', 'of', 'eating', 'options', 'around', 'including', 'restaurants', 'that', 'serve', 'dog', 'meat']

# %% [markdown]
# #### Training the Word2Vec model
#
# To train a Word2Vec model, we instantiate Word2Vec and pass it the text we have loaded before. You can check the available options for [instantiation](https://radimrehurek.com/gensim_3.8.3/models/word2vec.html#gensim.models.word2vec.Word2Vec) and for [training](https://radimrehurek.com/gensim_3.8.3/models/word2vec.html#gensim.models.word2vec.Word2Vec.train).
#
# Training a Word2Vec model takes time, depending on your hardware. In this particular case, expect training to take something between 5 to 10 minutes on an Intel Core-i7 16GB desktop. I know, that's a very wide range, but of course it depends on which other processes are running in the same machine...

# %%
from datetime import datetime

start_time = datetime.now()

model = gensim.models.Word2Vec(documents, vector_size=150, window=10, min_count=2, workers=10, sg=1)

print("Training time:", datetime.now() - start_time)
# Out:
# 2023-03-10 12:15:31,876 : INFO : collecting all words and their counts
# 2023-03-10 12:15:31,876 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2023-03-10 12:15:32,270 : INFO : PROGRESS: at sentence #10000, processed 1655714 words, keeping 25777 word types
# 2023-03-10 12:15:32,652 : INFO : PROGRESS: at sentence #20000, processed 3317863 words, keeping 35016 word types
# 2023-03-10 12:15:33,267 : INFO : PROGRESS: at sentence #30000, processed 5264072 words, keeping 47518 word types
# 2023-03-10 12:15:34,071 : INFO : PROGRESS: at sentence #40000, processed 7081746 words, keeping 56675 word types
# 2023-03-10 12:15:34,785 : INFO : PROGRESS: at sentence #50000, processed 9089491 words, keeping 63744 word types
# 2023-03-10 12:15:35,377 : INFO : PROGRESS: at sentence #60000, processed 11013726 words, keeping 76786 word types
# 2023-03-10 12:15:35,927 : INFO : PROGRESS: at sentence #70000, processed 12637528 words, keeping 83199 word types
# 2023-03-10 12:15:36,319 : INFO : PROGRESS: at sentence #80000, processed 14099754 words, keeping 88459 word types
# 2023-03-10 12:15:36,715 : INFO : PROGRESS: at sentence #90000, processed 15662152 words, keeping 93357 word types
# 2023-03-10 12:15:37,087 : INFO : PROGRESS: at sentence #100000, processed 17164490 words, keeping 97886 word types
# 2023-03-10 12:15:37,455 : INFO : PROGRESS: at sentence #110000, processed 18652295 words, keeping 102132 word types
# 2023-03-10 12:15:37,787 : INFO : PROGRESS: at sentence #120000, processed 20152532 words, keeping 105923 word types
# 2023-03-10 12:15:38,125 : INFO : PROGRESS: at sentence #130000, processed 21684333 words, keeping 110104 word types
# 2023-03-10 12:15:38,480 : INFO : PROGRESS: at sentence #140000, processed 23330209 words, keeping 114108 word types
# 2023-03-10 12:15:38,806 : INFO : PROGRESS: at sentence #150000, processed 24838757 words, keeping 118174 word types
# 2023-03-10 12:15:39,140 : INFO : PROGRESS: at sentence #160000, processed 26390913 words, keeping 118670 word types
# 2023-03-10 12:15:39,473 : INFO : PROGRESS: at sentence #170000, processed 27913919 words, keeping 123356 word types
# 2023-03-10 12:15:39,816 : INFO : PROGRESS: at sentence #180000, processed 29535615 words, keeping 126748 word types
# 2023-03-10 12:15:40,130 : INFO : PROGRESS: at sentence #190000, processed 31096462 words, keeping 129847 word types
# 2023-03-10 12:15:40,491 : INFO : PROGRESS: at sentence #200000, processed 32805274 words, keeping 133255 word types
# 2023-03-10 12:15:40,814 : INFO : PROGRESS: at sentence #210000, processed 34434201 words, keeping 136364 word types
# 2023-03-10 12:15:41,142 : INFO : PROGRESS: at sentence #220000, processed 36083485 words, keeping 139418 word types
# 2023-03-10 12:15:41,443 : INFO : PROGRESS: at sentence #230000, processed 37571765 words, keeping 142399 word types
# 2023-03-10 12:15:41,756 : INFO : PROGRESS: at sentence #240000, processed 39138193 words, keeping 145232 word types
# 2023-03-10 12:15:42,061 : INFO : PROGRESS: at sentence #250000, processed 40695052 words, keeping 147966 word types
# 2023-03-10 12:15:42,274 : INFO : collected 150059 word types from a corpus of 41519358 raw words and 255404 sentences
# 2023-03-10 12:15:42,275 : INFO : Creating a fresh vocabulary
# 2023-03-10 12:15:42,631 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=2 retains 70537 unique words (47.01% of original 150059, drops 79522)', 'datetime': '2023-03-10T12:15:42.630186', 'gensim': '4.3.1', 'python': '3.8.3 (tags/v3.8.3:6f8c832, May 13 2020, 22:37:02) [MSC v.1924 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'prepare_vocab'}
# 2023-03-10 12:15:42,631 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=2 leaves 41439836 word corpus (99.81% of original 41519358, drops 79522)', 'datetime': '2023-03-10T12:15:42.631193', 'gensim': '4.3.1', 'python': '3.8.3 (tags/v3.8.3:6f8c832, May 13 2020, 22:37:02) [MSC v.1924 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'prepare_vocab'}
# 2023-03-10 12:15:43,130 : INFO : deleting the raw counts dictionary of 150059 items
# 2023-03-10 12:15:43,138 : INFO : sample=0.001 downsamples 55 most-common words
# 2023-03-10 12:15:43,139 : INFO : Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 30349251.36700416 word corpus (73.2%% of prior 41439836)', 'datetime': '2023-03-10T12:15:43.139139', 'gensim': '4.3.1', 'python': '3.8.3 (tags/v3.8.3:6f8c832, May 13 2020, 22:37:02) [MSC v.1924 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'prepare_vocab'}
# 2023-03-10 12:15:43,857 : INFO : estimated required memory for 70537 words and 150 dimensions: 119912900 bytes
# 2023-03-10 12:15:43,858 : INFO : resetting layer weights
# 2023-03-10 12:15:43,950 : INFO : Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2023-03-10T12:15:43.950098', 'gensim': '4.3.1', 'python': '3.8.3 (tags/v3.8.3:6f8c832, May 13 2020, 22:37:02) [MSC v.1924 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'build_vocab'}
# 2023-03-10 12:15:43,951 : INFO : Word2Vec lifecycle event {'msg': 'training model with 10 workers on 70537 vocabulary and 150 features, using sg=1 hs=0 sample=0.001 negative=5 window=10 shrink_windows=True', 'datetime': '2023-03-10T12:15:43.951097', 'gensim': '4.3.1', 'python': '3.8.3 (tags/v3.8.3:6f8c832, May 13 2020, 22:37:02) [MSC v.1924 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'train'}
# 2023-03-10 12:15:45,126 : INFO : EPOCH 0 - PROGRESS: at 0.49% examples, 151080 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:15:46,271 : INFO : EPOCH 0 - PROGRESS: at 1.04% examples, 154599 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:15:47,287 : INFO : EPOCH 0 - PROGRESS: at 1.70% examples, 166365 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:15:48,288 : INFO : EPOCH 0 - PROGRESS: at 2.08% examples, 155840 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:15:49,345 : INFO : EPOCH 0 - PROGRESS: at 2.64% examples, 157308 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:15:50,470 : INFO : EPOCH 0 - PROGRESS: at 3.30% examples, 160093 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:15:51,482 : INFO : EPOCH 0 - PROGRESS: at 3.89% examples, 162568 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:15:52,566 : INFO : EPOCH 0 - PROGRESS: at 4.50% examples, 163948 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:15:53,702 : INFO : EPOCH 0 - PROGRESS: at 5.21% examples, 167106 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:15:54,743 : INFO : EPOCH 0 - PROGRESS: at 5.90% examples, 170938 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:15:55,746 : INFO : EPOCH 0 - PROGRESS: at 6.51% examples, 171706 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:15:56,796 : INFO : EPOCH 0 - PROGRESS: at 7.14% examples, 172842 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:15:57,932 : INFO : EPOCH 0 - PROGRESS: at 7.79% examples, 174200 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:15:58,942 : INFO : EPOCH 0 - PROGRESS: at 8.41% examples, 174906 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:16:00,015 : INFO : EPOCH 0 - PROGRESS: at 8.99% examples, 175770 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:16:01,046 : INFO : EPOCH 0 - PROGRESS: at 9.58% examples, 176927 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:16:02,072 : INFO : EPOCH 0 - PROGRESS: at 10.02% examples, 177185 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:16:03,073 : INFO : EPOCH 0 - PROGRESS: at 10.55% examples, 177760 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:16:04,170 : INFO : EPOCH 0 - PROGRESS: at 11.07% examples, 177653 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:16:05,207 : INFO : EPOCH 0 - PROGRESS: at 11.58% examples, 178172 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:16:06,227 : INFO : EPOCH 0 - PROGRESS: at 12.05% examples, 178351 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:16:07,228 : INFO : EPOCH 0 - PROGRESS: at 12.55% examples, 179032 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:16:08,258 : INFO : EPOCH 0 - PROGRESS: at 13.19% examples, 179468 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:16:09,274 : INFO : EPOCH 0 - PROGRESS: at 13.75% examples, 179654 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:16:10,290 : INFO : EPOCH 0 - PROGRESS: at 14.24% examples, 179544 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:16:11,377 : INFO : EPOCH 0 - PROGRESS: at 14.83% examples, 180059 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:16:12,423 : INFO : EPOCH 0 - PROGRESS: at 15.44% examples, 180049 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:16:13,492 : INFO : EPOCH 0 - PROGRESS: at 15.98% examples, 180395 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:16:14,519 : INFO : EPOCH 0 - PROGRESS: at 16.53% examples, 180674 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:16:15,532 : INFO : EPOCH 0 - PROGRESS: at 17.03% examples, 180569 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:16:16,587 : INFO : EPOCH 0 - PROGRESS: at 17.53% examples, 180720 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:16:17,656 : INFO : EPOCH 0 - PROGRESS: at 18.03% examples, 180315 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:16:18,781 : INFO : EPOCH 0 - PROGRESS: at 18.56% examples, 179873 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:16:19,849 : INFO : EPOCH 0 - PROGRESS: at 19.02% examples, 179680 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:16:20,878 : INFO : EPOCH 0 - PROGRESS: at 19.44% examples, 179316 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:16:21,917 : INFO : EPOCH 0 - PROGRESS: at 19.89% examples, 178762 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:16:23,050 : INFO : EPOCH 0 - PROGRESS: at 20.41% examples, 178697 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:16:24,103 : INFO : EPOCH 0 - PROGRESS: at 20.84% examples, 178502 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:16:25,133 : INFO : EPOCH 0 - PROGRESS: at 21.56% examples, 177789 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:16:26,231 : INFO : EPOCH 0 - PROGRESS: at 21.94% examples, 176743 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:16:27,231 : INFO : EPOCH 0 - PROGRESS: at 22.42% examples, 176649 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:16:28,268 : INFO : EPOCH 0 - PROGRESS: at 22.95% examples, 177068 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:16:29,270 : INFO : EPOCH 0 - PROGRESS: at 23.35% examples, 176807 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:16:30,283 : INFO : EPOCH 0 - PROGRESS: at 23.82% examples, 176978 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:16:31,322 : INFO : EPOCH 0 - PROGRESS: at 24.18% examples, 176113 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:16:32,414 : INFO : EPOCH 0 - PROGRESS: at 24.46% examples, 174370 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:16:33,479 : INFO : EPOCH 0 - PROGRESS: at 24.83% examples, 172955 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:16:34,509 : INFO : EPOCH 0 - PROGRESS: at 25.22% examples, 171263 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:16:35,515 : INFO : EPOCH 0 - PROGRESS: at 25.60% examples, 170014 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:16:36,582 : INFO : EPOCH 0 - PROGRESS: at 25.88% examples, 168085 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:16:37,614 : INFO : EPOCH 0 - PROGRESS: at 26.36% examples, 167150 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:16:38,672 : INFO : EPOCH 0 - PROGRESS: at 26.77% examples, 166030 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:16:39,760 : INFO : EPOCH 0 - PROGRESS: at 27.16% examples, 164597 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:16:40,762 : INFO : EPOCH 0 - PROGRESS: at 27.60% examples, 163730 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:16:41,781 : INFO : EPOCH 0 - PROGRESS: at 27.94% examples, 162341 words/s, in_qsize 20, out_qsize 1
# 2023-03-10 12:16:42,974 : INFO : EPOCH 0 - PROGRESS: at 28.31% examples, 160890 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:16:44,114 : INFO : EPOCH 0 - PROGRESS: at 28.83% examples, 160240 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:16:45,353 : INFO : EPOCH 0 - PROGRESS: at 29.02% examples, 157823 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:16:47,103 : INFO : EPOCH 0 - PROGRESS: at 29.21% examples, 154353 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:16:48,126 : INFO : EPOCH 0 - PROGRESS: at 29.57% examples, 153451 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:16:49,409 : INFO : EPOCH 0 - PROGRESS: at 29.85% examples, 151651 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:16:50,456 : INFO : EPOCH 0 - PROGRESS: at 30.31% examples, 151430 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:16:51,493 : INFO : EPOCH 0 - PROGRESS: at 30.76% examples, 150830 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:16:52,563 : INFO : EPOCH 0 - PROGRESS: at 31.13% examples, 149850 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:16:53,652 : INFO : EPOCH 0 - PROGRESS: at 31.73% examples, 149675 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:16:54,705 : INFO : EPOCH 0 - PROGRESS: at 32.10% examples, 149068 words/s, in_qsize 20, out_qsize 1
# 2023-03-10 12:16:55,716 : INFO : EPOCH 0 - PROGRESS: at 32.29% examples, 147669 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:16:56,748 : INFO : EPOCH 0 - PROGRESS: at 32.64% examples, 146954 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:16:57,774 : INFO : EPOCH 0 - PROGRESS: at 33.18% examples, 146959 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:16:58,806 : INFO : EPOCH 0 - PROGRESS: at 33.78% examples, 147547 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:16:59,813 : INFO : EPOCH 0 - PROGRESS: at 34.39% examples, 147790 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:17:00,832 : INFO : EPOCH 0 - PROGRESS: at 34.98% examples, 148273 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:17:01,845 : INFO : EPOCH 0 - PROGRESS: at 35.59% examples, 148476 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:17:02,849 : INFO : EPOCH 0 - PROGRESS: at 36.22% examples, 148781 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:17:03,853 : INFO : EPOCH 0 - PROGRESS: at 36.82% examples, 149078 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:17:04,882 : INFO : EPOCH 0 - PROGRESS: at 37.38% examples, 149233 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:17:05,885 : INFO : EPOCH 0 - PROGRESS: at 38.14% examples, 149944 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:17:06,926 : INFO : EPOCH 0 - PROGRESS: at 38.77% examples, 150146 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:17:08,065 : INFO : EPOCH 0 - PROGRESS: at 39.49% examples, 150608 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:17:09,084 : INFO : EPOCH 0 - PROGRESS: at 40.21% examples, 151089 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:17:10,133 : INFO : EPOCH 0 - PROGRESS: at 40.84% examples, 151427 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:17:11,205 : INFO : EPOCH 0 - PROGRESS: at 41.65% examples, 151798 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:17:12,218 : INFO : EPOCH 0 - PROGRESS: at 42.30% examples, 152164 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:17:13,275 : INFO : EPOCH 0 - PROGRESS: at 42.92% examples, 152460 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:17:14,346 : INFO : EPOCH 0 - PROGRESS: at 43.56% examples, 152577 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:17:15,349 : INFO : EPOCH 0 - PROGRESS: at 44.18% examples, 152721 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:17:16,369 : INFO : EPOCH 0 - PROGRESS: at 44.96% examples, 153214 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:17:17,389 : INFO : EPOCH 0 - PROGRESS: at 45.64% examples, 153546 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:17:18,515 : INFO : EPOCH 0 - PROGRESS: at 46.34% examples, 153860 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:17:19,547 : INFO : EPOCH 0 - PROGRESS: at 46.99% examples, 154297 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:17:20,559 : INFO : EPOCH 0 - PROGRESS: at 47.59% examples, 154477 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:17:21,588 : INFO : EPOCH 0 - PROGRESS: at 48.26% examples, 154849 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:17:22,590 : INFO : EPOCH 0 - PROGRESS: at 48.90% examples, 155031 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:17:23,599 : INFO : EPOCH 0 - PROGRESS: at 49.59% examples, 155483 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:17:24,624 : INFO : EPOCH 0 - PROGRESS: at 50.25% examples, 155755 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:17:25,717 : INFO : EPOCH 0 - PROGRESS: at 50.94% examples, 156068 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:17:26,775 : INFO : EPOCH 0 - PROGRESS: at 51.64% examples, 156478 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:17:27,851 : INFO : EPOCH 0 - PROGRESS: at 52.27% examples, 156726 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:17:28,890 : INFO : EPOCH 0 - PROGRESS: at 52.87% examples, 157027 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:17:29,933 : INFO : EPOCH 0 - PROGRESS: at 53.50% examples, 157380 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:17:30,934 : INFO : EPOCH 0 - PROGRESS: at 54.12% examples, 157598 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:17:31,939 : INFO : EPOCH 0 - PROGRESS: at 54.77% examples, 157950 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:17:32,985 : INFO : EPOCH 0 - PROGRESS: at 55.53% examples, 158154 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:17:33,986 : INFO : EPOCH 0 - PROGRESS: at 56.18% examples, 158425 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:17:35,080 : INFO : EPOCH 0 - PROGRESS: at 56.88% examples, 158692 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:17:36,094 : INFO : EPOCH 0 - PROGRESS: at 57.52% examples, 158868 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:17:37,105 : INFO : EPOCH 0 - PROGRESS: at 58.02% examples, 158844 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:17:38,167 : INFO : EPOCH 0 - PROGRESS: at 58.73% examples, 159137 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:17:39,255 : INFO : EPOCH 0 - PROGRESS: at 59.38% examples, 159268 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:17:40,401 : INFO : EPOCH 0 - PROGRESS: at 60.08% examples, 159450 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:17:41,452 : INFO : EPOCH 0 - PROGRESS: at 60.75% examples, 159633 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:17:42,482 : INFO : EPOCH 0 - PROGRESS: at 61.38% examples, 159830 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:17:43,544 : INFO : EPOCH 0 - PROGRESS: at 61.93% examples, 159806 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:17:44,560 : INFO : EPOCH 0 - PROGRESS: at 62.56% examples, 159895 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:17:45,580 : INFO : EPOCH 0 - PROGRESS: at 63.18% examples, 159981 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:17:46,606 : INFO : EPOCH 0 - PROGRESS: at 63.78% examples, 159880 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:17:47,673 : INFO : EPOCH 0 - PROGRESS: at 64.47% examples, 159901 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:17:48,674 : INFO : EPOCH 0 - PROGRESS: at 64.98% examples, 159763 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:17:49,681 : INFO : EPOCH 0 - PROGRESS: at 65.51% examples, 159858 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:17:50,704 : INFO : EPOCH 0 - PROGRESS: at 65.98% examples, 159817 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:17:51,727 : INFO : EPOCH 0 - PROGRESS: at 66.61% examples, 159987 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:17:52,770 : INFO : EPOCH 0 - PROGRESS: at 67.28% examples, 160197 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:17:53,798 : INFO : EPOCH 0 - PROGRESS: at 67.96% examples, 160426 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:17:54,814 : INFO : EPOCH 0 - PROGRESS: at 68.53% examples, 160552 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:17:55,822 : INFO : EPOCH 0 - PROGRESS: at 69.19% examples, 160797 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:17:56,837 : INFO : EPOCH 0 - PROGRESS: at 69.79% examples, 160974 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:17:57,873 : INFO : EPOCH 0 - PROGRESS: at 70.30% examples, 161015 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:17:58,987 : INFO : EPOCH 0 - PROGRESS: at 70.86% examples, 160976 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:18:00,060 : INFO : EPOCH 0 - PROGRESS: at 71.61% examples, 161298 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:18:01,160 : INFO : EPOCH 0 - PROGRESS: at 72.28% examples, 161480 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:18:02,191 : INFO : EPOCH 0 - PROGRESS: at 73.00% examples, 161678 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:18:03,238 : INFO : EPOCH 0 - PROGRESS: at 73.75% examples, 161909 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:18:04,267 : INFO : EPOCH 0 - PROGRESS: at 74.38% examples, 162106 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:18:05,343 : INFO : EPOCH 0 - PROGRESS: at 75.04% examples, 162345 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:18:06,387 : INFO : EPOCH 0 - PROGRESS: at 75.70% examples, 162636 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:18:07,417 : INFO : EPOCH 0 - PROGRESS: at 76.30% examples, 162869 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:18:08,466 : INFO : EPOCH 0 - PROGRESS: at 76.92% examples, 162985 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:18:09,472 : INFO : EPOCH 0 - PROGRESS: at 77.44% examples, 163041 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:18:10,541 : INFO : EPOCH 0 - PROGRESS: at 78.03% examples, 163172 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:18:11,651 : INFO : EPOCH 0 - PROGRESS: at 78.75% examples, 163410 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:18:12,665 : INFO : EPOCH 0 - PROGRESS: at 79.45% examples, 163701 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:18:13,701 : INFO : EPOCH 0 - PROGRESS: at 80.02% examples, 163774 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:18:14,702 : INFO : EPOCH 0 - PROGRESS: at 80.66% examples, 164019 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:18:15,741 : INFO : EPOCH 0 - PROGRESS: at 81.28% examples, 164130 words/s, in_qsize 18, out_qsize 1
# 2023-03-10 12:18:16,741 : INFO : EPOCH 0 - PROGRESS: at 81.87% examples, 164187 words/s, in_qsize 18, out_qsize 1
# 2023-03-10 12:18:17,768 : INFO : EPOCH 0 - PROGRESS: at 82.55% examples, 164402 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:18:18,811 : INFO : EPOCH 0 - PROGRESS: at 83.17% examples, 164460 words/s, in_qsize 19, out_qsize 1
# 2023-03-10 12:18:19,815 : INFO : EPOCH 0 - PROGRESS: at 83.80% examples, 164691 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:18:20,819 : INFO : EPOCH 0 - PROGRESS: at 84.41% examples, 164874 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:18:21,843 : INFO : EPOCH 0 - PROGRESS: at 85.00% examples, 165027 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:18:22,899 : INFO : EPOCH 0 - PROGRESS: at 85.67% examples, 165199 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:18:23,911 : INFO : EPOCH 0 - PROGRESS: at 86.39% examples, 165413 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:18:24,919 : INFO : EPOCH 0 - PROGRESS: at 87.08% examples, 165545 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:18:25,922 : INFO : EPOCH 0 - PROGRESS: at 87.81% examples, 165728 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:18:26,972 : INFO : EPOCH 0 - PROGRESS: at 88.54% examples, 165941 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:18:27,990 : INFO : EPOCH 0 - PROGRESS: at 89.28% examples, 166194 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:18:29,029 : INFO : EPOCH 0 - PROGRESS: at 89.89% examples, 166194 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:18:30,045 : INFO : EPOCH 0 - PROGRESS: at 90.50% examples, 166226 words/s, in_qsize 18, out_qsize 1
# 2023-03-10 12:18:31,106 : INFO : EPOCH 0 - PROGRESS: at 91.18% examples, 166335 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:18:32,136 : INFO : EPOCH 0 - PROGRESS: at 91.82% examples, 166434 words/s, in_qsize 20, out_qsize 1
# 2023-03-10 12:18:33,231 : INFO : EPOCH 0 - PROGRESS: at 92.51% examples, 166508 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:18:34,238 : INFO : EPOCH 0 - PROGRESS: at 93.15% examples, 166749 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:18:35,278 : INFO : EPOCH 0 - PROGRESS: at 93.85% examples, 166874 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:18:36,312 : INFO : EPOCH 0 - PROGRESS: at 94.48% examples, 166924 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:18:37,328 : INFO : EPOCH 0 - PROGRESS: at 95.01% examples, 166862 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:18:38,411 : INFO : EPOCH 0 - PROGRESS: at 95.63% examples, 166825 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:18:39,425 : INFO : EPOCH 0 - PROGRESS: at 96.12% examples, 166762 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:18:40,455 : INFO : EPOCH 0 - PROGRESS: at 96.68% examples, 166688 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:18:41,472 : INFO : EPOCH 0 - PROGRESS: at 97.20% examples, 166539 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:18:42,566 : INFO : EPOCH 0 - PROGRESS: at 97.65% examples, 166280 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:18:43,589 : INFO : EPOCH 0 - PROGRESS: at 98.27% examples, 166339 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:18:44,608 : INFO : EPOCH 0 - PROGRESS: at 98.91% examples, 166362 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:18:45,715 : INFO : EPOCH 0 - PROGRESS: at 99.52% examples, 166345 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:18:46,526 : INFO : EPOCH 0: training on 41519358 raw words (30348599 effective words) took 182.5s, 166334 effective words/s
# 2023-03-10 12:18:47,601 : INFO : EPOCH 1 - PROGRESS: at 0.33% examples, 102456 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:18:48,609 : INFO : EPOCH 1 - PROGRESS: at 0.91% examples, 146830 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:18:49,633 : INFO : EPOCH 1 - PROGRESS: at 1.47% examples, 152027 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:18:50,668 : INFO : EPOCH 1 - PROGRESS: at 2.02% examples, 154041 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:18:51,674 : INFO : EPOCH 1 - PROGRESS: at 2.40% examples, 147564 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:18:52,852 : INFO : EPOCH 1 - PROGRESS: at 2.84% examples, 140651 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:18:53,911 : INFO : EPOCH 1 - PROGRESS: at 3.36% examples, 141977 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:18:55,011 : INFO : EPOCH 1 - PROGRESS: at 3.85% examples, 140595 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:18:56,081 : INFO : EPOCH 1 - PROGRESS: at 4.43% examples, 142984 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:18:57,088 : INFO : EPOCH 1 - PROGRESS: at 5.00% examples, 145813 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:18:58,168 : INFO : EPOCH 1 - PROGRESS: at 5.57% examples, 147675 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:18:59,195 : INFO : EPOCH 1 - PROGRESS: at 6.08% examples, 148161 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:19:00,201 : INFO : EPOCH 1 - PROGRESS: at 6.57% examples, 148348 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:19:01,248 : INFO : EPOCH 1 - PROGRESS: at 6.95% examples, 145131 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:19:02,256 : INFO : EPOCH 1 - PROGRESS: at 7.47% examples, 146790 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:19:03,260 : INFO : EPOCH 1 - PROGRESS: at 7.90% examples, 146598 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:19:04,279 : INFO : EPOCH 1 - PROGRESS: at 8.43% examples, 147057 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:19:05,339 : INFO : EPOCH 1 - PROGRESS: at 8.93% examples, 147971 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:19:06,384 : INFO : EPOCH 1 - PROGRESS: at 9.38% examples, 147783 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:19:07,391 : INFO : EPOCH 1 - PROGRESS: at 9.74% examples, 147148 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:19:08,439 : INFO : EPOCH 1 - PROGRESS: at 10.09% examples, 146681 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:19:09,462 : INFO : EPOCH 1 - PROGRESS: at 10.49% examples, 146445 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:19:10,473 : INFO : EPOCH 1 - PROGRESS: at 10.87% examples, 146250 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:19:11,508 : INFO : EPOCH 1 - PROGRESS: at 11.24% examples, 145649 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:19:12,550 : INFO : EPOCH 1 - PROGRESS: at 11.64% examples, 145937 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:19:13,641 : INFO : EPOCH 1 - PROGRESS: at 12.00% examples, 145333 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:19:14,669 : INFO : EPOCH 1 - PROGRESS: at 12.42% examples, 145635 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:19:15,722 : INFO : EPOCH 1 - PROGRESS: at 12.94% examples, 146313 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:19:16,745 : INFO : EPOCH 1 - PROGRESS: at 13.53% examples, 147324 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:19:17,758 : INFO : EPOCH 1 - PROGRESS: at 14.03% examples, 148534 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:19:18,772 : INFO : EPOCH 1 - PROGRESS: at 14.56% examples, 149427 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:19:19,807 : INFO : EPOCH 1 - PROGRESS: at 15.09% examples, 150421 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:19:20,857 : INFO : EPOCH 1 - PROGRESS: at 15.60% examples, 150466 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:19:21,890 : INFO : EPOCH 1 - PROGRESS: at 15.96% examples, 149963 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:19:23,023 : INFO : EPOCH 1 - PROGRESS: at 16.51% examples, 150608 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:19:24,029 : INFO : EPOCH 1 - PROGRESS: at 17.04% examples, 151749 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:19:25,040 : INFO : EPOCH 1 - PROGRESS: at 17.46% examples, 151910 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:19:26,102 : INFO : EPOCH 1 - PROGRESS: at 17.91% examples, 152012 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:19:27,135 : INFO : EPOCH 1 - PROGRESS: at 18.37% examples, 152201 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:19:28,206 : INFO : EPOCH 1 - PROGRESS: at 18.80% examples, 152071 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:19:29,274 : INFO : EPOCH 1 - PROGRESS: at 19.24% examples, 152441 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:19:30,313 : INFO : EPOCH 1 - PROGRESS: at 19.70% examples, 152933 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:19:31,363 : INFO : EPOCH 1 - PROGRESS: at 20.13% examples, 153164 words/s, in_qsize 20, out_qsize 1
# 2023-03-10 12:19:32,379 : INFO : EPOCH 1 - PROGRESS: at 20.60% examples, 153863 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:19:33,389 : INFO : EPOCH 1 - PROGRESS: at 20.96% examples, 153626 words/s, in_qsize 20, out_qsize 1
# 2023-03-10 12:19:34,414 : INFO : EPOCH 1 - PROGRESS: at 21.79% examples, 154317 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:19:35,419 : INFO : EPOCH 1 - PROGRESS: at 22.28% examples, 154971 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:19:36,439 : INFO : EPOCH 1 - PROGRESS: at 22.80% examples, 155704 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:19:37,535 : INFO : EPOCH 1 - PROGRESS: at 23.22% examples, 155755 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:19:38,538 : INFO : EPOCH 1 - PROGRESS: at 23.69% examples, 156341 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:19:39,542 : INFO : EPOCH 1 - PROGRESS: at 24.18% examples, 157026 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:19:40,554 : INFO : EPOCH 1 - PROGRESS: at 24.67% examples, 157425 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:19:41,562 : INFO : EPOCH 1 - PROGRESS: at 25.36% examples, 157813 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:19:42,577 : INFO : EPOCH 1 - PROGRESS: at 26.07% examples, 158570 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:19:43,617 : INFO : EPOCH 1 - PROGRESS: at 26.77% examples, 158853 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:19:44,741 : INFO : EPOCH 1 - PROGRESS: at 27.54% examples, 159252 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:19:45,760 : INFO : EPOCH 1 - PROGRESS: at 28.20% examples, 159442 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:19:46,986 : INFO : EPOCH 1 - PROGRESS: at 28.90% examples, 159541 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:19:47,999 : INFO : EPOCH 1 - PROGRESS: at 29.53% examples, 159833 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:19:49,065 : INFO : EPOCH 1 - PROGRESS: at 30.23% examples, 160454 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:19:50,077 : INFO : EPOCH 1 - PROGRESS: at 30.95% examples, 160884 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:19:51,181 : INFO : EPOCH 1 - PROGRESS: at 31.76% examples, 161245 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:19:52,201 : INFO : EPOCH 1 - PROGRESS: at 32.43% examples, 161696 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:19:53,221 : INFO : EPOCH 1 - PROGRESS: at 33.14% examples, 162247 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:19:54,305 : INFO : EPOCH 1 - PROGRESS: at 33.70% examples, 162321 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:19:55,305 : INFO : EPOCH 1 - PROGRESS: at 34.39% examples, 162807 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:19:56,472 : INFO : EPOCH 1 - PROGRESS: at 35.01% examples, 162884 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:19:57,517 : INFO : EPOCH 1 - PROGRESS: at 35.73% examples, 163330 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:19:58,536 : INFO : EPOCH 1 - PROGRESS: at 36.44% examples, 163613 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:19:59,545 : INFO : EPOCH 1 - PROGRESS: at 37.06% examples, 163926 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:20:00,554 : INFO : EPOCH 1 - PROGRESS: at 37.69% examples, 164213 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:20:01,555 : INFO : EPOCH 1 - PROGRESS: at 38.42% examples, 164604 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:20:02,602 : INFO : EPOCH 1 - PROGRESS: at 39.04% examples, 164614 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:20:03,608 : INFO : EPOCH 1 - PROGRESS: at 39.68% examples, 164902 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:20:04,647 : INFO : EPOCH 1 - PROGRESS: at 40.38% examples, 165191 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:20:05,697 : INFO : EPOCH 1 - PROGRESS: at 41.14% examples, 165472 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:20:06,772 : INFO : EPOCH 1 - PROGRESS: at 41.94% examples, 165773 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:20:07,803 : INFO : EPOCH 1 - PROGRESS: at 42.53% examples, 165962 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:20:08,810 : INFO : EPOCH 1 - PROGRESS: at 43.18% examples, 166118 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:20:09,865 : INFO : EPOCH 1 - PROGRESS: at 43.89% examples, 166362 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:20:10,878 : INFO : EPOCH 1 - PROGRESS: at 44.65% examples, 166670 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:20:11,878 : INFO : EPOCH 1 - PROGRESS: at 45.27% examples, 166742 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:20:12,887 : INFO : EPOCH 1 - PROGRESS: at 45.96% examples, 167048 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:20:14,007 : INFO : EPOCH 1 - PROGRESS: at 46.64% examples, 167215 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:20:15,075 : INFO : EPOCH 1 - PROGRESS: at 47.32% examples, 167552 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:20:16,091 : INFO : EPOCH 1 - PROGRESS: at 47.93% examples, 167589 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:20:17,188 : INFO : EPOCH 1 - PROGRESS: at 48.62% examples, 167714 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:20:18,201 : INFO : EPOCH 1 - PROGRESS: at 49.34% examples, 167975 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:20:19,257 : INFO : EPOCH 1 - PROGRESS: at 50.00% examples, 168156 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:20:20,317 : INFO : EPOCH 1 - PROGRESS: at 50.67% examples, 168331 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:20:21,341 : INFO : EPOCH 1 - PROGRESS: at 51.19% examples, 168179 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:20:22,413 : INFO : EPOCH 1 - PROGRESS: at 51.69% examples, 167794 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:20:23,415 : INFO : EPOCH 1 - PROGRESS: at 52.23% examples, 167761 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:20:24,478 : INFO : EPOCH 1 - PROGRESS: at 52.75% examples, 167637 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:20:25,507 : INFO : EPOCH 1 - PROGRESS: at 53.29% examples, 167703 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:20:26,508 : INFO : EPOCH 1 - PROGRESS: at 53.92% examples, 167900 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:20:27,563 : INFO : EPOCH 1 - PROGRESS: at 54.53% examples, 167877 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:20:28,589 : INFO : EPOCH 1 - PROGRESS: at 55.12% examples, 167746 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:20:29,591 : INFO : EPOCH 1 - PROGRESS: at 55.70% examples, 167655 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:20:30,686 : INFO : EPOCH 1 - PROGRESS: at 56.27% examples, 167486 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:20:31,723 : INFO : EPOCH 1 - PROGRESS: at 56.82% examples, 167352 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:20:32,727 : INFO : EPOCH 1 - PROGRESS: at 57.31% examples, 167063 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:20:33,809 : INFO : EPOCH 1 - PROGRESS: at 57.70% examples, 166517 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:20:34,838 : INFO : EPOCH 1 - PROGRESS: at 58.23% examples, 166331 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:20:35,874 : INFO : EPOCH 1 - PROGRESS: at 58.70% examples, 166010 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:20:36,920 : INFO : EPOCH 1 - PROGRESS: at 59.25% examples, 165876 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:20:37,993 : INFO : EPOCH 1 - PROGRESS: at 59.80% examples, 165645 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:20:39,019 : INFO : EPOCH 1 - PROGRESS: at 60.15% examples, 165107 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:20:40,030 : INFO : EPOCH 1 - PROGRESS: at 60.71% examples, 164980 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:20:41,107 : INFO : EPOCH 1 - PROGRESS: at 61.20% examples, 164755 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:20:42,216 : INFO : EPOCH 1 - PROGRESS: at 61.69% examples, 164425 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:20:43,224 : INFO : EPOCH 1 - PROGRESS: at 62.18% examples, 164250 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:20:44,283 : INFO : EPOCH 1 - PROGRESS: at 62.73% examples, 164051 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:20:45,339 : INFO : EPOCH 1 - PROGRESS: at 63.41% examples, 164120 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:20:46,369 : INFO : EPOCH 1 - PROGRESS: at 64.12% examples, 164208 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:20:47,476 : INFO : EPOCH 1 - PROGRESS: at 64.84% examples, 164245 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:20:48,478 : INFO : EPOCH 1 - PROGRESS: at 65.39% examples, 164378 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:20:49,478 : INFO : EPOCH 1 - PROGRESS: at 65.93% examples, 164500 words/s, in_qsize 18, out_qsize 1
# 2023-03-10 12:20:50,492 : INFO : EPOCH 1 - PROGRESS: at 66.61% examples, 164768 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:20:51,584 : INFO : EPOCH 1 - PROGRESS: at 67.26% examples, 164872 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:20:52,624 : INFO : EPOCH 1 - PROGRESS: at 67.91% examples, 164945 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:20:53,658 : INFO : EPOCH 1 - PROGRESS: at 68.49% examples, 165018 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:20:54,667 : INFO : EPOCH 1 - PROGRESS: at 69.13% examples, 165180 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:20:55,679 : INFO : EPOCH 1 - PROGRESS: at 69.73% examples, 165390 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:20:56,716 : INFO : EPOCH 1 - PROGRESS: at 70.28% examples, 165454 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:20:57,738 : INFO : EPOCH 1 - PROGRESS: at 70.90% examples, 165655 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:20:58,815 : INFO : EPOCH 1 - PROGRESS: at 71.56% examples, 165726 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:20:59,844 : INFO : EPOCH 1 - PROGRESS: at 72.17% examples, 165856 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:21:00,939 : INFO : EPOCH 1 - PROGRESS: at 72.89% examples, 165948 words/s, in_qsize 20, out_qsize 1
# 2023-03-10 12:21:02,043 : INFO : EPOCH 1 - PROGRESS: at 73.61% examples, 166029 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:21:03,060 : INFO : EPOCH 1 - PROGRESS: at 74.21% examples, 166110 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:21:04,097 : INFO : EPOCH 1 - PROGRESS: at 74.84% examples, 166214 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:21:05,125 : INFO : EPOCH 1 - PROGRESS: at 75.40% examples, 166289 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:21:06,171 : INFO : EPOCH 1 - PROGRESS: at 75.99% examples, 166433 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:21:07,353 : INFO : EPOCH 1 - PROGRESS: at 76.53% examples, 166308 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:21:08,419 : INFO : EPOCH 1 - PROGRESS: at 77.17% examples, 166483 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:21:09,495 : INFO : EPOCH 1 - PROGRESS: at 77.70% examples, 166435 words/s, in_qsize 20, out_qsize 1
# 2023-03-10 12:21:10,510 : INFO : EPOCH 1 - PROGRESS: at 78.29% examples, 166563 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:21:11,518 : INFO : EPOCH 1 - PROGRESS: at 78.86% examples, 166588 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:21:12,525 : INFO : EPOCH 1 - PROGRESS: at 79.52% examples, 166778 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:21:13,548 : INFO : EPOCH 1 - PROGRESS: at 80.07% examples, 166794 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:21:14,557 : INFO : EPOCH 1 - PROGRESS: at 80.60% examples, 166773 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:21:15,572 : INFO : EPOCH 1 - PROGRESS: at 81.23% examples, 166937 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:21:16,611 : INFO : EPOCH 1 - PROGRESS: at 81.80% examples, 166888 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:21:17,664 : INFO : EPOCH 1 - PROGRESS: at 82.40% examples, 166916 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:21:18,700 : INFO : EPOCH 1 - PROGRESS: at 83.02% examples, 166965 words/s, in_qsize 18, out_qsize 1
# 2023-03-10 12:21:19,702 : INFO : EPOCH 1 - PROGRESS: at 83.63% examples, 167094 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:21:20,735 : INFO : EPOCH 1 - PROGRESS: at 84.24% examples, 167232 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:21:21,739 : INFO : EPOCH 1 - PROGRESS: at 84.81% examples, 167349 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:21:22,899 : INFO : EPOCH 1 - PROGRESS: at 85.42% examples, 167345 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:21:23,908 : INFO : EPOCH 1 - PROGRESS: at 86.02% examples, 167370 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:21:24,964 : INFO : EPOCH 1 - PROGRESS: at 86.78% examples, 167574 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:21:26,004 : INFO : EPOCH 1 - PROGRESS: at 87.44% examples, 167615 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:21:27,031 : INFO : EPOCH 1 - PROGRESS: at 88.16% examples, 167798 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:21:28,092 : INFO : EPOCH 1 - PROGRESS: at 88.87% examples, 167865 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:21:29,183 : INFO : EPOCH 1 - PROGRESS: at 89.57% examples, 168027 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:21:30,221 : INFO : EPOCH 1 - PROGRESS: at 90.23% examples, 168064 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:21:31,235 : INFO : EPOCH 1 - PROGRESS: at 90.86% examples, 168126 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:21:32,392 : INFO : EPOCH 1 - PROGRESS: at 91.48% examples, 168042 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:21:33,420 : INFO : EPOCH 1 - PROGRESS: at 91.95% examples, 167786 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:21:34,441 : INFO : EPOCH 1 - PROGRESS: at 92.49% examples, 167708 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:21:35,444 : INFO : EPOCH 1 - PROGRESS: at 93.00% examples, 167691 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:21:36,463 : INFO : EPOCH 1 - PROGRESS: at 93.31% examples, 167280 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:21:37,466 : INFO : EPOCH 1 - PROGRESS: at 93.70% examples, 166890 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:21:38,596 : INFO : EPOCH 1 - PROGRESS: at 93.94% examples, 166212 words/s, in_qsize 18, out_qsize 1
# 2023-03-10 12:21:39,719 : INFO : EPOCH 1 - PROGRESS: at 94.28% examples, 165682 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:21:40,745 : INFO : EPOCH 1 - PROGRESS: at 94.55% examples, 165159 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:21:41,860 : INFO : EPOCH 1 - PROGRESS: at 95.01% examples, 164893 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:21:42,938 : INFO : EPOCH 1 - PROGRESS: at 95.52% examples, 164667 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:21:43,978 : INFO : EPOCH 1 - PROGRESS: at 96.03% examples, 164636 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:21:45,006 : INFO : EPOCH 1 - PROGRESS: at 96.55% examples, 164496 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:21:46,012 : INFO : EPOCH 1 - PROGRESS: at 97.20% examples, 164616 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:21:47,043 : INFO : EPOCH 1 - PROGRESS: at 97.69% examples, 164505 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:21:48,077 : INFO : EPOCH 1 - PROGRESS: at 98.28% examples, 164486 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:21:49,100 : INFO : EPOCH 1 - PROGRESS: at 98.94% examples, 164556 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:21:50,152 : INFO : EPOCH 1 - PROGRESS: at 99.58% examples, 164633 words/s, in_qsize 17, out_qsize 0
# 2023-03-10 12:21:50,639 : INFO : EPOCH 1: training on 41519358 raw words (30347626 effective words) took 184.1s, 164843 effective words/s
# 2023-03-10 12:21:51,680 : INFO : EPOCH 2 - PROGRESS: at 0.47% examples, 148149 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:21:52,798 : INFO : EPOCH 2 - PROGRESS: at 1.02% examples, 154976 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:21:53,964 : INFO : EPOCH 2 - PROGRESS: at 1.74% examples, 165709 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:21:54,984 : INFO : EPOCH 2 - PROGRESS: at 2.32% examples, 169859 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:21:55,986 : INFO : EPOCH 2 - PROGRESS: at 2.85% examples, 166390 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:21:57,001 : INFO : EPOCH 2 - PROGRESS: at 3.48% examples, 170467 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:21:58,012 : INFO : EPOCH 2 - PROGRESS: at 4.01% examples, 168670 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:21:59,035 : INFO : EPOCH 2 - PROGRESS: at 4.63% examples, 170525 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:22:00,072 : INFO : EPOCH 2 - PROGRESS: at 5.10% examples, 167025 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:22:01,147 : INFO : EPOCH 2 - PROGRESS: at 5.64% examples, 165645 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:22:02,156 : INFO : EPOCH 2 - PROGRESS: at 6.06% examples, 162353 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:22:03,234 : INFO : EPOCH 2 - PROGRESS: at 6.57% examples, 161014 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:22:04,255 : INFO : EPOCH 2 - PROGRESS: at 7.18% examples, 162724 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:22:05,298 : INFO : EPOCH 2 - PROGRESS: at 7.71% examples, 162878 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:22:06,307 : INFO : EPOCH 2 - PROGRESS: at 8.23% examples, 162938 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:22:07,328 : INFO : EPOCH 2 - PROGRESS: at 8.77% examples, 162861 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:22:08,418 : INFO : EPOCH 2 - PROGRESS: at 9.17% examples, 160993 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:22:09,502 : INFO : EPOCH 2 - PROGRESS: at 9.63% examples, 160481 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:22:10,590 : INFO : EPOCH 2 - PROGRESS: at 10.05% examples, 160366 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:22:11,618 : INFO : EPOCH 2 - PROGRESS: at 10.55% examples, 161144 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:22:12,701 : INFO : EPOCH 2 - PROGRESS: at 10.98% examples, 160686 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:22:13,748 : INFO : EPOCH 2 - PROGRESS: at 11.47% examples, 161175 words/s, in_qsize 19, out_qsize 0
# ...
# 2023-03-10 12:28:19,534 : INFO : EPOCH 3 - PROGRESS: at 75.93% examples, 109636 words/s, in_qsize 20, out_qsize 1
# 2023-03-10 12:28:20,654 : INFO : EPOCH 3 - PROGRESS: at 76.14% examples, 109394 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:28:21,662 : INFO : EPOCH 3 - PROGRESS: at 76.34% examples, 109217 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:28:22,847 : INFO : EPOCH 3 - PROGRESS: at 76.56% examples, 108948 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:28:23,881 : INFO : EPOCH 3 - PROGRESS: at 76.87% examples, 108829 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:28:24,997 : INFO : EPOCH 3 - PROGRESS: at 77.07% examples, 108568 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:28:26,083 : INFO : EPOCH 3 - PROGRESS: at 77.29% examples, 108355 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:28:27,253 : INFO : EPOCH 3 - PROGRESS: at 77.48% examples, 108074 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:28:28,298 : INFO : EPOCH 3 - PROGRESS: at 77.65% examples, 107821 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:28:29,326 : INFO : EPOCH 3 - PROGRESS: at 77.89% examples, 107645 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:28:30,400 : INFO : EPOCH 3 - PROGRESS: at 78.13% examples, 107450 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:28:31,434 : INFO : EPOCH 3 - PROGRESS: at 78.27% examples, 107181 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:28:32,550 : INFO : EPOCH 3 - PROGRESS: at 78.47% examples, 106904 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:28:33,696 : INFO : EPOCH 3 - PROGRESS: at 78.75% examples, 106743 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:28:34,778 : INFO : EPOCH 3 - PROGRESS: at 78.99% examples, 106581 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:28:35,832 : INFO : EPOCH 3 - PROGRESS: at 79.24% examples, 106374 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:28:36,848 : INFO : EPOCH 3 - PROGRESS: at 79.39% examples, 106125 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:28:38,045 : INFO : EPOCH 3 - PROGRESS: at 79.63% examples, 105885 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:28:39,094 : INFO : EPOCH 3 - PROGRESS: at 79.87% examples, 105717 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:28:40,146 : INFO : EPOCH 3 - PROGRESS: at 80.09% examples, 105549 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:28:41,191 : INFO : EPOCH 3 - PROGRESS: at 80.36% examples, 105416 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:28:42,232 : INFO : EPOCH 3 - PROGRESS: at 80.56% examples, 105225 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:28:43,243 : INFO : EPOCH 3 - PROGRESS: at 80.74% examples, 105016 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:28:44,244 : INFO : EPOCH 3 - PROGRESS: at 80.95% examples, 104875 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:28:45,318 : INFO : EPOCH 3 - PROGRESS: at 81.12% examples, 104612 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:28:46,454 : INFO : EPOCH 3 - PROGRESS: at 81.37% examples, 104415 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:28:47,592 : INFO : EPOCH 3 - PROGRESS: at 81.61% examples, 104222 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:28:48,648 : INFO : EPOCH 3 - PROGRESS: at 81.87% examples, 104064 words/s, in_qsize 18, out_qsize 1
# 2023-03-10 12:28:49,724 : INFO : EPOCH 3 - PROGRESS: at 82.23% examples, 104045 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:28:50,754 : INFO : EPOCH 3 - PROGRESS: at 82.43% examples, 103842 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:28:51,856 : INFO : EPOCH 3 - PROGRESS: at 82.69% examples, 103671 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:28:52,890 : INFO : EPOCH 3 - PROGRESS: at 82.84% examples, 103408 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:28:53,956 : INFO : EPOCH 3 - PROGRESS: at 82.95% examples, 103107 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:28:55,234 : INFO : EPOCH 3 - PROGRESS: at 83.19% examples, 102866 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:28:56,370 : INFO : EPOCH 3 - PROGRESS: at 83.43% examples, 102684 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:28:57,596 : INFO : EPOCH 3 - PROGRESS: at 83.65% examples, 102468 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:28:58,802 : INFO : EPOCH 3 - PROGRESS: at 83.88% examples, 102263 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:28:59,949 : INFO : EPOCH 3 - PROGRESS: at 84.15% examples, 102110 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:29:00,968 : INFO : EPOCH 3 - PROGRESS: at 84.33% examples, 101955 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:29:01,985 : INFO : EPOCH 3 - PROGRESS: at 84.53% examples, 101826 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:29:03,037 : INFO : EPOCH 3 - PROGRESS: at 84.81% examples, 101744 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:29:04,180 : INFO : EPOCH 3 - PROGRESS: at 85.04% examples, 101598 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:29:05,182 : INFO : EPOCH 3 - PROGRESS: at 85.37% examples, 101592 words/s, in_qsize 20, out_qsize 1
# 2023-03-10 12:29:06,191 : INFO : EPOCH 3 - PROGRESS: at 85.54% examples, 101392 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:29:07,240 : INFO : EPOCH 3 - PROGRESS: at 85.81% examples, 101259 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:29:08,281 : INFO : EPOCH 3 - PROGRESS: at 86.04% examples, 101131 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:29:09,387 : INFO : EPOCH 3 - PROGRESS: at 86.32% examples, 100977 words/s, in_qsize 18, out_qsize 1
# 2023-03-10 12:29:10,477 : INFO : EPOCH 3 - PROGRESS: at 86.58% examples, 100835 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:29:11,595 : INFO : EPOCH 3 - PROGRESS: at 86.84% examples, 100681 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:29:12,678 : INFO : EPOCH 3 - PROGRESS: at 87.03% examples, 100461 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:29:13,996 : INFO : EPOCH 3 - PROGRESS: at 87.26% examples, 100207 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:29:15,040 : INFO : EPOCH 3 - PROGRESS: at 87.70% examples, 100250 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:29:16,122 : INFO : EPOCH 3 - PROGRESS: at 88.22% examples, 100406 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:29:17,295 : INFO : EPOCH 3 - PROGRESS: at 88.54% examples, 100293 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:29:18,311 : INFO : EPOCH 3 - PROGRESS: at 88.81% examples, 100183 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:29:19,360 : INFO : EPOCH 3 - PROGRESS: at 89.06% examples, 100063 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:29:20,427 : INFO : EPOCH 3 - PROGRESS: at 89.30% examples, 99938 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:29:21,507 : INFO : EPOCH 3 - PROGRESS: at 89.55% examples, 99805 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:29:22,543 : INFO : EPOCH 3 - PROGRESS: at 89.79% examples, 99692 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:29:23,653 : INFO : EPOCH 3 - PROGRESS: at 90.07% examples, 99553 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:29:24,691 : INFO : EPOCH 3 - PROGRESS: at 90.29% examples, 99415 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:29:25,971 : INFO : EPOCH 3 - PROGRESS: at 90.54% examples, 99220 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:29:27,023 : INFO : EPOCH 3 - PROGRESS: at 90.81% examples, 99103 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:29:28,123 : INFO : EPOCH 3 - PROGRESS: at 91.06% examples, 98971 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:29:29,307 : INFO : EPOCH 3 - PROGRESS: at 91.28% examples, 98786 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:29:30,320 : INFO : EPOCH 3 - PROGRESS: at 91.48% examples, 98636 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:29:31,348 : INFO : EPOCH 3 - PROGRESS: at 91.68% examples, 98484 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:29:32,368 : INFO : EPOCH 3 - PROGRESS: at 91.98% examples, 98435 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:29:33,448 : INFO : EPOCH 3 - PROGRESS: at 92.35% examples, 98391 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:29:34,578 : INFO : EPOCH 3 - PROGRESS: at 92.55% examples, 98252 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:29:35,639 : INFO : EPOCH 3 - PROGRESS: at 92.75% examples, 98116 words/s, in_qsize 20, out_qsize 0
# 2023-03-10 12:29:36,672 : INFO : EPOCH 3 - PROGRESS: at 92.89% examples, 97915 words/s, in_qsize 18, out_qsize 1
# 2023-03-10 12:29:37,716 : INFO : EPOCH 3 - PROGRESS: at 93.24% examples, 97959 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:29:38,748 : INFO : EPOCH 3 - PROGRESS: at 93.80% examples, 98133 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:29:39,910 : INFO : EPOCH 3 - PROGRESS: at 94.36% examples, 98289 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:29:40,927 : INFO : EPOCH 3 - PROGRESS: at 94.87% examples, 98466 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:29:41,933 : INFO : EPOCH 3 - PROGRESS: at 95.38% examples, 98617 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:29:42,994 : INFO : EPOCH 3 - PROGRESS: at 95.90% examples, 98803 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:29:43,995 : INFO : EPOCH 3 - PROGRESS: at 96.44% examples, 98982 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:29:45,012 : INFO : EPOCH 3 - PROGRESS: at 97.05% examples, 99246 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:29:46,033 : INFO : EPOCH 3 - PROGRESS: at 97.65% examples, 99505 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:29:47,112 : INFO : EPOCH 3 - PROGRESS: at 98.28% examples, 99751 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:29:48,131 : INFO : EPOCH 3 - PROGRESS: at 98.92% examples, 100015 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:29:49,185 : INFO : EPOCH 3 - PROGRESS: at 99.56% examples, 100287 words/s, in_qsize 17, out_qsize 0
# 2023-03-10 12:29:49,780 : INFO : EPOCH 3: training on 41519358 raw words (30347994 effective words) took 302.0s, 100483 effective words/s
# 2023-03-10 12:29:50,797 : INFO : EPOCH 4 - PROGRESS: at 0.36% examples, 115439 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:29:51,819 : INFO : EPOCH 4 - PROGRESS: at 0.89% examples, 146191 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:29:52,842 : INFO : EPOCH 4 - PROGRESS: at 1.55% examples, 161418 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:29:53,888 : INFO : EPOCH 4 - PROGRESS: at 2.14% examples, 165755 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:29:54,906 : INFO : EPOCH 4 - PROGRESS: at 2.72% examples, 166497 words/s, in_qsize 20, out_qsize 1
# 2023-03-10 12:29:55,951 : INFO : EPOCH 4 - PROGRESS: at 3.41% examples, 172209 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:29:56,951 : INFO : EPOCH 4 - PROGRESS: at 4.01% examples, 173329 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:29:57,966 : INFO : EPOCH 4 - PROGRESS: at 4.58% examples, 173020 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:29:58,994 : INFO : EPOCH 4 - PROGRESS: at 5.07% examples, 170150 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:30:00,009 : INFO : EPOCH 4 - PROGRESS: at 5.60% examples, 168709 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:30:01,042 : INFO : EPOCH 4 - PROGRESS: at 6.08% examples, 166606 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:30:02,204 : INFO : EPOCH 4 - PROGRESS: at 6.64% examples, 164942 words/s, in_qsize 19, out_qsize 0
# 2023-03-10 12:30:03,210 : INFO : EPOCH 4 - PROGRESS: at 7.18% examples, 164933 words/s, in_qsize 20, out_qsize 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\radio\OneDrive\Ambiente de Trabalho\PwoGwammingUwU\NLP-EXERCICIOS\word-embeddings_.ipynb Cell 11 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/radio/OneDrive/Ambiente%20de%20Trabalho/PwoGwammingUwU/NLP-EXERCICIOS/word-embeddings_.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> from datetime import datetime
#       <a href='vscode-notebook-cell:/c%3A/Users/radio/OneDrive/Ambiente%20de%20Trabalho/PwoGwammingUwU/NLP-EXERCICIOS/word-embeddings_.ipynb#X13sZmlsZQ%3D%3D?line=2'>3</a> start_time = datetime.now()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/radio/OneDrive/Ambiente%20de%20Trabalho/PwoGwammingUwU/NLP-EXERCICIOS/word-embeddings_.ipynb#X13sZmlsZQ%3D%3D?line=4'>5</a> model = gensim.models.Word2Vec(documents, vector_size=150, window=10, min_count=2, workers=10, sg=1)
#       <a href='vscode-notebook-cell:/c%3A/Users/radio/OneDrive/Ambiente%20de%20Trabalho/PwoGwammingUwU/NLP-EXERCICIOS/word-embeddings_.ipynb#X13sZmlsZQ%3D%3D?line=6'>7</a> print("Training time:", datetime.now() - start_time)
#
# File c:\Python38\lib\site-packages\gensim\models\word2vec.py:430, in Word2Vec.__init__(self, sentences, corpus_file, vector_size, alpha, window, min_count, max_vocab_size, sample, seed, workers, min_alpha, sg, hs, negative, ns_exponent, cbow_mean, hashfxn, epochs, null_word, trim_rule, sorted_vocab, batch_words, compute_loss, callbacks, comment, max_final_vocab, shrink_windows)
#     428     self._check_corpus_sanity(corpus_iterable=corpus_iterable, corpus_file=corpus_file, passes=(epochs + 1))
#     429     self.build_vocab(corpus_iterable=corpus_iterable, corpus_file=corpus_file, trim_rule=trim_rule)
# --> 430     self.train(
#     431         corpus_iterable=corpus_iterable, corpus_file=corpus_file, total_examples=self.corpus_count,
#     432         total_words=self.corpus_total_words, epochs=self.epochs, start_alpha=self.alpha,
#     433         end_alpha=self.min_alpha, compute_loss=self.compute_loss, callbacks=callbacks)
#     434 else:
#     435     if trim_rule is not None:
#
# File c:\Python38\lib\site-packages\gensim\models\word2vec.py:1073, in Word2Vec.train(self, corpus_iterable, corpus_file, total_examples, total_words, epochs, start_alpha, end_alpha, word_count, queue_factor, report_delay, compute_loss, callbacks, **kwargs)
#    1070     callback.on_epoch_begin(self)
#    1072 if corpus_iterable is not None:
# -> 1073     trained_word_count_epoch, raw_word_count_epoch, job_tally_epoch = self._train_epoch(
#    1074         corpus_iterable, cur_epoch=cur_epoch, total_examples=total_examples,
#    1075         total_words=total_words, queue_factor=queue_factor, report_delay=report_delay,
#    1076         callbacks=callbacks, **kwargs)
#    1077 else:
#    1078     trained_word_count_epoch, raw_word_count_epoch, job_tally_epoch = self._train_epoch_corpusfile(
#    1079         corpus_file, cur_epoch=cur_epoch, total_examples=total_examples, total_words=total_words,
#    1080         callbacks=callbacks, **kwargs)
#
# File c:\Python38\lib\site-packages\gensim\models\word2vec.py:1434, in Word2Vec._train_epoch(self, data_iterable, cur_epoch, total_examples, total_words, queue_factor, report_delay, callbacks)
#    1431     thread.daemon = True  # make interrupting the process with ctrl+c easier
#    1432     thread.start()
# -> 1434 trained_word_count, raw_word_count, job_tally = self._log_epoch_progress(
#    1435     progress_queue, job_queue, cur_epoch=cur_epoch, total_examples=total_examples,
#    1436     total_words=total_words, report_delay=report_delay, is_corpus_file_mode=False,
#    1437 )
#    1439 return trained_word_count, raw_word_count, job_tally
#
# File c:\Python38\lib\site-packages\gensim\models\word2vec.py:1289, in Word2Vec._log_epoch_progress(self, progress_queue, job_queue, cur_epoch, total_examples, total_words, report_delay, is_corpus_file_mode)
#    1286 unfinished_worker_count = self.workers
#    1288 while unfinished_worker_count > 0:
# -> 1289     report = progress_queue.get()  # blocks if workers too slow
#    1290     if report is None:  # a thread reporting that it finished
#    1291         unfinished_worker_count -= 1
#
# File c:\Python38\lib\queue.py:170, in Queue.get(self, block, timeout)
#     168 elif timeout is None:
#     169     while not self._qsize():
# --> 170         self.not_empty.wait()
#     171 elif timeout < 0:
#     172     raise ValueError("'timeout' must be a non-negative number")
#
# File c:\Python38\lib\threading.py:302, in Condition.wait(self, timeout)
#     300 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301     if timeout is None:
# --> 302         waiter.acquire()
#     303         gotit = True
#     304     else:
#
# KeyboardInterrupt:

# %% [markdown]
# #### Exploiting the Word2Vec model
#
# We can now inspect the word embeddings that we have trained. We can start by looking at the embeddings of a specific word:

# %%
# embeddings
model.wv.get_vector("dirty")

# %% [markdown]
# Which are the words most similar to this one?

# %%
# similarity
w1 = "dirty"
model.wv.most_similar(positive=w1)

# %% [markdown]
# You can also limit to a smaller number of hits:

# %%
# look up top 6 words similar to 'polite'
w1 = ["polite"]
model.wv.most_similar(positive=w1, topn=6)

# %%
# look up top 6 words similar to 'france'
w1 = ["france"]
model.wv.most_similar(positive=w1, topn=6)

# %% [markdown]
# We can also provide to *most_similar* not only positive concepts, but also negative ones. This allows us to do some arithmetic on the vector representations for certain sets of words!
#
# The famous example **king - man + woman = queen** goes as follows:

# %%
# arithmetic: vec(“king”) - vec(“man”) + vec(“woman”) =~ vec(“queen”)
w1 = ["king",'woman']
w2 = ['man']
model.wv.most_similar(positive=w1, negative=w2, topn=1)

# %% [markdown]
# We can get the similarity scores for specific word pairs.

# %%
# similarity between two different words
model.wv.similarity(w1="dirty", w2="smelly")

# %%
# similarity between two identical words
model.wv.similarity(w1="dirty", w2="dirty")

# %%
# similarity between two unrelated words
model.wv.similarity(w1="dirty", w2="clean")

# %% [markdown]
# And we can check which word in a list of words is an intruder:

# %%
model.wv.doesnt_match(["cat", "dog", "france"])

# %%
model.wv.doesnt_match(["bed", "pillow", "duvet", "shower"])

# %%
model.wv.doesnt_match(["car", "bicycle", "plane", "skate"])

# %%
model.wv.doesnt_match(["car", "bicycle", "bus", "trolley"])

# %% [markdown]
# Make your own experiments! Try to find out:
# - Which word is most similar to *lift*?
# - What are the 3 words most similar to *crab*?
# - How similar are the words *waitress* and *waiter*?
# - If you take *portugal*, remove *lisbon*, and add *dublin*, what do you get?

# %%
# your code here

# %% [markdown]
# #### Saving and loading a Word2Vec model
#
# You can save a trained model so that you are able to load it again in the future, and optionally continue training it.

# %%
# save full model (including trainable vectors to resume training)
model.save("reviews_model")

# %%
# load full model
model = gensim.models.Word2Vec.load("reviews_model")

# %% [markdown]
# #### Saving and loading the word embeddings
#
# If you're sure you won't be training the model any longer, you can save its *KeyedVectors* (the word embeddings).

# %%
# save model word vectors
model.wv.save("reviews_wv")

# %% [markdown]
# After saving the embeddings, you can load them and use them.

# %%
# load model word vectors
wv = gensim.models.KeyedVectors.load("reviews_wv")

print(wv.most_similar(positive="lift", topn=1))

# %% [markdown]
# ## Visualization
#
# Word embeddings can be visualized by reducing dimensionality of the words to 2 dimensions using [tSNE](https://scikit-learn.org/stable/modules/generated/sklearn.manifold.TSNE.html).
#
# Given enough training data, we can observe certain patterns in the vector space, including:
# - Semantic relations: words like *cat*, *dog*, *cow*, etc. have a tendency to lie close by.
# - Syntactic relations: words like *run*, *running* or *cut*, *cutting* lie close together.
# - Arithmetic properties such as *King - Man = Queen - Woman*.

# %%
from sklearn.manifold import TSNE
import numpy as np
import matplotlib.pyplot as plt
import random


def reduce_dimensions(model, num_dimensions=2, words=[]):

    vectors = [] # positions in vector space
    labels = [] # keep track of words to label our data again later
    word_count = 0
    
    # if no word list is given, assume we want to use the whole data in the model
    if(words == []):
        words = model.wv.index_to_key

    for word in words:
        vectors.append(model.wv[word])
        labels.append(word)

    # convert both lists into numpy vectors for reduction
    vectors = np.asarray(vectors)
    labels = np.asarray(labels)

    # reduce using t-SNE
    tsne = TSNE(n_components=num_dimensions, random_state=0)
    vectors = tsne.fit_transform(vectors)

    return vectors, labels


# 2 dimension plotting
def plot_with_matplotlib(x_vals, y_vals, labels, words=[]):

    random.seed(0)
    
    x_vals_new = np.array([])
    y_vals_new = np.array([])
    labels_new = np.array([])
    if(words == []):
        # if no word list is given, assume we want to plot the whole data
        x_vals_new = x_vals
        y_vals_new = y_vals
        labels_new = labels
    else:
        for i in range(len(labels)):
            if(labels[i] in words):
                x_vals_new = np.append(x_vals_new,x_vals[i])
                y_vals_new = np.append(y_vals_new,y_vals[i])
                labels_new = np.append(labels_new,labels[i])
    
    plt.figure(figsize=(12, 12))
    plt.scatter(x_vals_new, y_vals_new)

    # apply labels
    for i in range(len(labels_new)):
        plt.annotate(labels_new[i], (x_vals_new[i], y_vals_new[i]))
    
    plt.show()

# %%
words = []
words.extend(["king", "man", "queen", "woman"])

vectors, labels = reduce_dimensions(model, 2, words)
x_vals = [v[0] for v in vectors]
y_vals = [v[1] for v in vectors]
print(x_vals, y_vals, labels)

# %%
plot_with_matplotlib(x_vals, y_vals, labels, ["king", "man", "queen", "woman"])

# %% [markdown]
# ## Portuguese embeddings
#
# A number of embeddings for Portuguese are available at [NILC](http://nilc.icmc.usp.br/embeddings), as well as at the [NLX-group](https://github.com/nlx-group/LX-DSemVectors).

# %%
from gensim.models import KeyedVectors

# takes a while to load...
model_pt = KeyedVectors.load_word2vec_format('skip_s100.txt')

# %%
# save model word vectors
model_pt.save("pt_wv")

# %%
# load model word vectors (much faster than the above)
model_pt = gensim.models.KeyedVectors.load("pt_wv")

# %%
model_pt.most_similar(positive=["cão"])

# %%
model_pt.most_similar(positive=["rei", "mulher"], negative=["homem"])

# %% [markdown]
# Make your own experiments!

# %%
# your code here
